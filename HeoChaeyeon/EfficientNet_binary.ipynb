# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#@title DataLoad [gdown] - cloud_binary
import gdown, zipfile, os
"https://drive.google.com/file/d/1738nG4c9ZbnAQkuBNxfrCBJcBn2CyQb5/view?usp=sharing"

file_id = '1738nG4c9ZbnAQkuBNxfrCBJcBn2CyQb5'
output = 'file.zip'

gdown.download(f'https://drive.google.com/uc?id={file_id}', output, quiet=False)

output_dir = 'cloud_binary'
os.makedirs(output_dir, exist_ok=True)

with zipfile.ZipFile(output, 'r') as z:
  z.extractall(output_dir)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1738nG4c9ZbnAQkuBNxfrCBJcBn2CyQb5
# From (redirected): https://drive.google.com/uc?id=1738nG4c9ZbnAQkuBNxfrCBJcBn2CyQb5&confirm=t&uuid=496e501d-afc2-453f-aa9b-b73e9566a150
# To: /content/file.zip
# 100%|██████████| 92.4M/92.4M [00:03<00:00, 27.2MB/s]

# %%
#@title DataLoad (cloud/data/train)
from sklearn.model_selection import train_test_split
def load_data(base_dir='cloud_binary/train'):
  images_path = []
  labels = []

  class_names = []

  for class_name in os.listdir(base_dir):
    class_name_path = os.path.join(base_dir, class_name)


    # 디렉토리인 경우만
    if os.path.isdir(class_name_path):
      for image_name in os.listdir(class_name_path):
        image_path = os.path.join(class_name_path, image_name)
        images_path.append(image_path)
        labels.append(class_name)

  return np.array(images_path), np.array(labels)

images_path, labels = load_data()
print(images_path.shape,labels.shape)
print(np.unique(labels))
# Out:
# (1000,) (1000,)
# ['Cloud' 'RainCloud']

# %%
#@title DataLoad (cloud/data/train)
from sklearn.model_selection import train_test_split
def load_data(base_dir='cloud_binary/test'):
  images_path = []
  labels = []

  class_names = []

  for class_name in os.listdir(base_dir):
    class_name_path = os.path.join(base_dir, class_name)


    # 디렉토리인 경우만
    if os.path.isdir(class_name_path):
      for image_name in os.listdir(class_name_path):
        image_path = os.path.join(class_name_path, image_name)
        images_path.append(image_path)
        labels.append(class_name)

  return np.array(images_path), np.array(labels)

test_images_path, test_labels = load_data()
print(test_images_path.shape, test_labels.shape)
print(np.unique(test_labels))
# Out:
# (200,) (200,)
# ['Cloud' 'RainCloud']

# %%
#@title train data split
from sklearn.model_selection  import train_test_split

train_images_path, val_images_path, train_labels, val_labels = train_test_split(images_path, labels, test_size=0.2, random_state=42)
train_images_path.shape, val_images_path.shape, train_labels.shape, val_labels.shape
# Out:
# ((800,), (200,), (800,), (200,))

# %%
#@title label에 대해 label_encoding
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
train_labels = label_encoder.fit_transform(train_labels)
train_labels = np.array(train_labels, dtype='int32')

val_labels = label_encoder.transform(val_labels)
val_labels = np.array(val_labels, dtype='int32')

test_labels=label_encoder.transform(test_labels)
test_labels = np.array(test_labels, dtype='int32')

# %%
#@title image_path to image_pixel

from tensorflow.keras.utils import Sequence
import cv2 # 이거 나중에 tensorflow로 바꿔

BATCH_SIZE = 32
IMAGE_SIZE = 224

class CloudSequence(Sequence):
  def __init__(self, images_path, labels, batch_size=BATCH_SIZE,
               image_size=IMAGE_SIZE, preprocess_function=None):
    self.images_path = images_path
    self.labels = labels
    self.batch_size = batch_size
    self.image_size = image_size
    self.preprocess_function = preprocess_function

  def __len__(self):
    return int(np.ceil(len(self.labels) / self.batch_size))

  def __getitem__(self, index):
    start = index * self.batch_size
    stop = (index + 1) * self.batch_size
    batch_images_path = self.images_path[start:stop]
    batch_labels = self.labels[start:stop]

    batch_images = np.zeros((batch_images_path.shape[0], self.image_size, self.image_size, 3), dtype=np.float32)

    for i,(image_path, label) in enumerate(zip(batch_images_path, batch_labels)):
        image = cv2.imread(image_path)
        image = cv2.resize(image, (self.image_size, self.image_size))
        # 스케일링
        if self.preprocess_function is not None:
          image = self.preprocess_function(image)
        batch_images[i]=image

    return (batch_images, batch_labels) if self.labels is not None else batch_images

# %%
from tensorflow.keras.applications.efficientnet import preprocess_input
tr_seq=CloudSequence(train_images_path, train_labels,preprocess_function=preprocess_input)
val_seq=CloudSequence(val_images_path, val_labels,preprocess_function=preprocess_input)
test_seq=CloudSequence(test_images_path, test_labels,preprocess_function=preprocess_input)

# %%
first_batch = next(iter(tr_seq))
first_batch[0].shape, first_batch[1].shape
# Out:
# ((32, 224, 224, 3), (32,))

# %%
first_batch_val = next(iter(val_seq))
first_batch_val[0].shape, first_batch_val[1].shape
# Out:
# ((32, 224, 224, 3), (32,))

# %%
#@title EfficientNet model 전이학습
from sklearn.model_selection import StratifiedShuffleSplit
from skimage.transform import resize
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pylab import rcParams
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau
import tensorflow as tf
import keras
from keras.models import Sequential, load_model
from keras.layers import Dropout, Dense, GlobalAveragePooling2D
from keras.optimizers import Adam
from tensorflow.keras.applications import EfficientNetB0


height = 224
width = 224
channels = 3
input_shape = (height, width, channels)
efnb0 = EfficientNetB0(weights='imagenet', include_top=False, input_shape=input_shape)

model = Sequential()
model.add(efnb0)
model.add(GlobalAveragePooling2D())
model.add(Dropout(0.3))
model.add(Dense(1, activation='sigmoid'))

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ efficientnetb0 (Functional)          │ (None, 7, 7, 1280)          │       4,049,571 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 1280)                │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 1280)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │           1,281 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 4,050,852 (15.45 MB)
#  Trainable params: 4,008,829 (15.29 MB)
#  Non-trainable params: 42,023 (164.16 KB)

# %%
#@title model_compile
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

model.compile(loss="binary_crossentropy",
              optimizer='adam',
              metrics=["accuracy"])


early_stopping_cb = EarlyStopping(patience=6, verbose=1, restore_best_weights=True)
reduce_lr_on_plateau_cb = ReduceLROnPlateau(patience=3, factor=0.5, verbose=1)

# %%
history = model.fit(
    tr_seq,
    epochs=30,
    validation_data=val_seq,
    callbacks=[early_stopping_cb, reduce_lr_on_plateau_cb]
)
# Out:
# Epoch 1/30
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 106s 765ms/step - accuracy: 0.8867 - loss: 0.2767 - val_accuracy: 0.8800 - val_loss: 0.2705 - learning_rate: 0.0010
# Epoch 2/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 23s 237ms/step - accuracy: 0.9993 - loss: 0.0220 - val_accuracy: 0.9100 - val_loss: 0.2491 - learning_rate: 0.0010
# Epoch 3/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 263ms/step - accuracy: 1.0000 - loss: 0.0073 - val_accuracy: 0.9350 - val_loss: 0.1410 - learning_rate: 0.0010
# Epoch 4/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 198ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.9650 - val_loss: 0.0842 - learning_rate: 0.0010
# Epoch 5/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 12s 254ms/step - accuracy: 1.0000 - loss: 7.4631e-04 - val_accuracy: 0.9700 - val_loss: 0.0725 - learning_rate: 0.0010
# Epoch 6/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 222ms/step - accuracy: 1.0000 - loss: 3.1372e-04 - val_accuracy: 0.9750 - val_loss: 0.0570 - learning_rate: 0.0010
# Epoch 7/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 192ms/step - accuracy: 1.0000 - loss: 3.7256e-04 - val_accuracy: 0.9800 - val_loss: 0.0410 - learning_rate: 0.0010
# Epoch 8/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 203ms/step - accuracy: 1.0000 - loss: 4.5730e-04 - val_accuracy: 0.9850 - val_loss: 0.0304 - learning_rate: 0.0010
# Epoch 9/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 210ms/step - accuracy: 1.0000 - loss: 1.9198e-04 - val_accuracy: 0.9850 - val_loss: 0.0236 - learning_rate: 0.0010
# Epoch 10/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 257ms/step - accuracy: 1.0000 - loss: 1.8594e-04 - val_accuracy: 0.9850 - val_loss: 0.0180 - learning_rate: 0.0010
# Epoch 11/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 207ms/step - accuracy: 1.0000 - loss: 1.9538e-04 - val_accuracy: 0.9900 - val_loss: 0.0129 - learning_rate: 0.0010
# Epoch 12/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 273ms/step - accuracy: 1.0000 - loss: 9.6232e-05 - val_accuracy: 0.9950 - val_loss: 0.0095 - learning_rate: 0.0010
# Epoch 13/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 215ms/step - accuracy: 1.0000 - loss: 1.1589e-04 - val_accuracy: 1.0000 - val_loss: 0.0080 - learning_rate: 0.0010
# Epoch 14/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 203ms/step - accuracy: 1.0000 - loss: 1.0225e-04 - val_accuracy: 1.0000 - val_loss: 0.0075 - learning_rate: 0.0010
# Epoch 15/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 224ms/step - accuracy: 1.0000 - loss: 8.6172e-05 - val_accuracy: 0.9950 - val_loss: 0.0074 - learning_rate: 0.0010
# Epoch 16/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 199ms/step - accuracy: 1.0000 - loss: 5.0831e-05 - val_accuracy: 0.9950 - val_loss: 0.0075 - learning_rate: 0.0010
# Epoch 17/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 233ms/step - accuracy: 1.0000 - loss: 5.4505e-05 - val_accuracy: 0.9950 - val_loss: 0.0072 - learning_rate: 0.0010
# Epoch 18/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 206ms/step - accuracy: 1.0000 - loss: 5.1858e-05 - val_accuracy: 1.0000 - val_loss: 0.0066 - learning_rate: 0.0010
# Epoch 19/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 284ms/step - accuracy: 1.0000 - loss: 5.5605e-05 - val_accuracy: 1.0000 - val_loss: 0.0062 - learning_rate: 0.0010
# Epoch 20/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 233ms/step - accuracy: 1.0000 - loss: 4.1020e-05 - val_accuracy: 1.0000 - val_loss: 0.0057 - learning_rate: 0.0010
# Epoch 21/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 295ms/step - accuracy: 1.0000 - loss: 3.3585e-05 - val_accuracy: 1.0000 - val_loss: 0.0052 - learning_rate: 0.0010
# Epoch 22/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 240ms/step - accuracy: 1.0000 - loss: 3.6698e-05 - val_accuracy: 1.0000 - val_loss: 0.0050 - learning_rate: 0.0010
# Epoch 23/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 277ms/step - accuracy: 1.0000 - loss: 4.2420e-05 - val_accuracy: 1.0000 - val_loss: 0.0047 - learning_rate: 0.0010
# Epoch 24/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 196ms/step - accuracy: 1.0000 - loss: 2.7500e-05 - val_accuracy: 1.0000 - val_loss: 0.0045 - learning_rate: 0.0010
# Epoch 25/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 248ms/step - accuracy: 1.0000 - loss: 2.6088e-05 - val_accuracy: 1.0000 - val_loss: 0.0044 - learning_rate: 0.0010
# Epoch 26/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 249ms/step - accuracy: 1.0000 - loss: 2.5348e-05 - val_accuracy: 1.0000 - val_loss: 0.0042 - learning_rate: 0.0010
# Epoch 27/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 223ms/step - accuracy: 1.0000 - loss: 6.0131e-05 - val_accuracy: 1.0000 - val_loss: 0.0041 - learning_rate: 0.0010
# Epoch 28/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 281ms/step - accuracy: 1.0000 - loss: 3.0116e-05 - val_accuracy: 1.0000 - val_loss: 0.0040 - learning_rate: 0.0010
# Epoch 29/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 195ms/step - accuracy: 1.0000 - loss: 3.4485e-05 - val_accuracy: 1.0000 - val_loss: 0.0040 - learning_rate: 0.0010
# Epoch 30/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 244ms/step - accuracy: 1.0000 - loss: 3.2310e-05 - val_accuracy: 1.0000 - val_loss: 0.0039 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 30.

# %% [markdown]
# ### **model save**
# - `model.save('model_name.h5')`
# - `model.save("model_name.keras")`
#   - 모델 저장 시 `.keras` 확장자를 사용하는 것은 파일 방식을 명확히 하고, Keras 모델임을 나타내기 위해 자주 사용됨
#   - 실제로 **.keras 확장자는 HDF5나 SavedModel 포맷의 저장 방식과 동일한 구조**

# %%
model.save('best_cloud_binary_EfficientNet.keras')
